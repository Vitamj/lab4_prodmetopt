# %% [markdown]
# # Исследование для лабораторной 4
#
# Ноутбук запускает обучение всех моделей, сохраняет таблицы и графики в `img/`.

# %%
from src.experiments import run_all_experiments

# %%
rows = run_all_experiments()
rows
